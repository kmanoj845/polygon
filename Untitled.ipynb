# %%
# from fastai.tabular.all import *
import os

# Get the current directory of the notebook
current_dir = os.getcwd()
current_dir
# # Set the working directory to one level above
os.chdir(os.path.dirname(current_dir))
os.getcwd()
# # Verify the change
# print("Current Working Directory:", os.getcwd())
# Out:
# '/home/mk47/kaggle'

# %%
# %load main.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/kaggle/kaggle/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3909, in InteractiveShell.find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3908 try:                                              # User namespace
# -> 3909     codeobj = eval(target, self.user_ns)
#    3910 except Exception as e:
#
# File <string>:1
#
# NameError: name 'main' is not defined
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_ipython().run_line_magic('load', 'main.py')
#
# File ~/kaggle/kaggle/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/kaggle/kaggle/lib/python3.10/site-packages/IPython/core/magics/code.py:359, in CodeMagics.load(self, arg_s)
#     357 opts,args = self.parse_options(arg_s,'yns:r:')
#     358 search_ns = 'n' in opts
# --> 359 contents = self.shell.find_user_code(args, search_ns=search_ns)
#     361 if 's' in opts:
#     362     try:
#
# File ~/kaggle/kaggle/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3911, in InteractiveShell.find_user_code(self, target, raw, py_only, skip_encoding_cookie, search_ns)
#    3909     codeobj = eval(target, self.user_ns)
#    3910 except Exception as e:
# -> 3911     raise ValueError(("'%s' was not found in history, as a file, url, "
#    3912                         "nor in the user namespace.") % target) from e
#    3914 if isinstance(codeobj, str):
#    3915     return codeobj
#
# ValueError: 'main.py' was not found in history, as a file, url, nor in the user namespace.

# %%
train_data = pd.read_csv(os.path.join(os.getcwd(), 'train.csv'))
test_data = pd.read_csv(os.path.join(os.getcwd(), 'test.csv'))

features = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

train_df = train_data[features]
train_df = train_df.dropna(subset=['Embarked'])
train_df['IsAgeMissing'] = train_df['Age'].isna().astype(int)
# y = train_df.pop('Survived')

# %%
categorical_features = ['Embarked', 'Sex', 'Pclass']

# %%
dls = TabularDataLoaders.from_df(df=train_df, y_names='Survived',
                                  cat_names = categorical_features,
                                  cont_names = ['Age', 'Fare', 'SibSp', 'Parch'],
                                  procs = [Categorify, FillMissing(FillStrategy.mode), Normalize])

learn = tabular_learner(dls, metrics=accuracy)
# Out:
# /home/mk47/kaggle/kaggle/lib/python3.10/site-packages/fastai/tabular/core.py:314: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   to[n].fillna(self.na_dict[n], inplace=True)

# %%
learn.fit_one_cycle(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.374214</td>
#       <td>0.325104</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.337752</td>
#       <td>0.296650</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.305800</td>
#       <td>0.232205</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.278101</td>
#       <td>0.203880</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.245249</td>
#       <td>0.183406</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.223765</td>
#       <td>0.164700</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.205289</td>
#       <td>0.158518</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.189238</td>
#       <td>0.165398</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.178513</td>
#       <td>0.159338</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.170725</td>
#       <td>0.154515</td>
#       <td>0.598870</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import seaborn as sns

train_data = pd.read_csv(os.path.join(os.getcwd(), 'train.csv'))
test_data = pd.read_csv(os.path.join(os.getcwd(), 'test.csv'))

features = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']

train_df = train_data[features]
train_df = train_df.dropna(subset=['Embarked'])
train_df['IsAgeMissing'] = train_df['Age'].isna().astype(int)
# y = train_df.pop('Survived')


# Apply the default theme
sns.set_theme()
sns.catplot(data=train_df, kind="swarm", x="Survived", y="Age", hue="Sex")
# Out:
# /home/mk47/kaggle/kaggle/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /home/mk47/kaggle/kaggle/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Embarked</th>
#       <th>Sex</th>
#       <th>Pclass</th>
#       <th>Age_na</th>
#       <th>Age</th>
#       <th>Fare</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Survived</th>
#       <th>Survived_pred</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>-0.347201</td>
#       <td>-0.471864</td>
#       <td>-0.473654</td>
#       <td>-0.471155</td>
#       <td>0.0</td>
#       <td>-0.016905</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>-0.347201</td>
#       <td>-0.321141</td>
#       <td>0.442764</td>
#       <td>-0.471155</td>
#       <td>0.0</td>
#       <td>0.082496</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>-0.870600</td>
#       <td>1.599672</td>
#       <td>-0.473654</td>
#       <td>1.995482</td>
#       <td>1.0</td>
#       <td>0.847494</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>-0.122887</td>
#       <td>-0.354493</td>
#       <td>0.442764</td>
#       <td>-0.471155</td>
#       <td>0.0</td>
#       <td>0.090926</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>2.0</td>
#       <td>-0.347201</td>
#       <td>0.497492</td>
#       <td>-0.473654</td>
#       <td>-0.471155</td>
#       <td>1.0</td>
#       <td>0.271824</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>0.325742</td>
#       <td>-0.471864</td>
#       <td>-0.473654</td>
#       <td>-0.471155</td>
#       <td>0.0</td>
#       <td>0.188546</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>0.325742</td>
#       <td>-0.326207</td>
#       <td>2.275601</td>
#       <td>-0.471155</td>
#       <td>1.0</td>
#       <td>0.506253</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>1.0</td>
#       <td>0.475284</td>
#       <td>-0.237040</td>
#       <td>0.442764</td>
#       <td>0.762163</td>
#       <td>1.0</td>
#       <td>0.207163</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>0.550056</td>
#       <td>0.165733</td>
#       <td>-0.473654</td>
#       <td>-0.471155</td>
#       <td>0.0</td>
#       <td>0.561999</td>
#     </tr>
#   </tbody>
# </table>
